# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
data_banjir = pd.read_excel('C:/Users/ivanm/Documents/DOCUMENTS/BELAJAR/TETRIS/Project/Data Bencana.xlsx')

# %%
data_banjir.head(5)
# Out:
#    No.  ID Kabupaten Tanggal Kejadian Kejadian  \
# 0    1          5304       2022-06-30   BANJIR
# 1    2          1709       2022-06-30   BANJIR
# 2    3          1701       2022-06-30   BANJIR
# 3    4          2104       2022-06-30   BANJIR
# 4    5          6201       2022-06-30   BANJIR
#
#                                               Lokasi             Kabupaten  \
# 0  Kec. Kualin  Ds. Toineke Kec.Amanatun Selatan ...  TIMOR TENGAH SELATAN
# 1  Kec. Talang Empat Ds. Pulau Panggung Ds. Jaya ...       BENGKULU TENGAH
# 2                     Kec. Pino Raya Ds.Telaga dalam      BENGKULU SELATAN
# 3  Kec. Singkep Kel. Dabo Lama Ds. Batu Berdaun D...                LINGGA
# 4  Kec. Pangkalan Banteng  Ds. Sungai Hijau Kec. ...    KOTAWARINGIN BARAT
#
#               Provinsi Kronologi & Dokumentasi  \
# 0  NUSA TENGGARA TIMUR                     NaN
# 1             BENGKULU                     NaN
# 2             BENGKULU                     NaN
# ...

# %%
data_banjir['Penyebab'].fillna(data_banjir['Kronologi & Dokumentasi'], inplace=True)

# %%
banjir_bogor = data_banjir[data_banjir['Kabupaten'] == 'BOGOR']

# %%
banjir_bogor
# Out:
#          No.  ID Kabupaten Tanggal Kejadian Kejadian  \
# 28        29          3201       2022-06-22   BANJIR
# 29        30          3201       2022-06-22   BANJIR
# 69        70          3201       2022-06-09   BANJIR
# 86        87          3201       2022-05-31   BANJIR
# 87        88          3201       2022-05-31   BANJIR
# ...      ...           ...              ...      ...
# 11757  11758          3201       2010-02-12   BANJIR
# 11765  11766          3201       2010-02-10   BANJIR
# 11770  11771          3201       2010-02-09   BANJIR
# 11772  11773          3201       2010-02-09   BANJIR
# 11933  11934          3201       2010-01-01   BANJIR
#
#                                                   Lokasi Kabupaten  \
# 28     Kec. Leuwiliang Ds.  Purasari Kp. tanjungsari ...     BOGOR
# 29                           Kec. Pamijahan Ds. Cibunian     BOGOR
# 69                         Kec. Cigombong Ds. Wates Jaya     BOGOR
# ...

# %%
banjir_bogor['Lokasi'].describe()
# Out:
# count                               146
# unique                              133
# top       Kec. Cisarua Ds. Tugu Selatan
# freq                                  5
# Name: Lokasi, dtype: object

# %%
banjir_bogor['Lokasi'].value_counts()
# Out:
# Kec. Cisarua Ds. Tugu Selatan                        5
# KEC BOJONGGEDE                                       4
# KEC CIOMAS                                           3
# KEC CIBINONG                                         2
# Kec. Pamijahan Ds. Cibunian                          2
#                                                     ..
# KEC CISEENG                                          1
# Kec. Leuwiliang  Ds. Leuwimekar Kampung Neglasari    1
# Kec. Sukajaya Ds. Jayaraharja                        1
# Kec. Cibungbulang  Ds. Cemplang                      1
# Kec. Caringin Ds. Lemah Duhur                        1
# Name: Lokasi, Length: 133, dtype: int64

# %%
banjir_bogor['Lokasi'].unique()
# Out:
# array(['Kec. Leuwiliang Ds.  Purasari Kp. tanjungsari Kp.cisalada Kp.Cisarua',
#        'Kec. Pamijahan Ds. Cibunian', 'Kec. Cigombong Ds. Wates Jaya',
#        'Kec.  Cisarua Ds. Kopo Ds. Tugu Utara Ds. Batu Layang Kec. Ciawi Ds. Bendungan Kec. Megamendung Ds. Sukamahi',
#        'Kec. Cisarua Ds. Tugu Selatan',
#        'Kec. Megamendung  Ds. Pasir Angin', 'Kec. Cibinong Kel. Pabuaran',
#        'Kec. Caringin Ds. Lemah Duhur',
#        'Kec. Tanjungsari Ds. Cibadak Ds. Sukarasa',
#        'Kec. Bojonggede Ds.  Pabuaran Kec. Gunung Putri Ds. Bojong Kulur',
#        'Kec. Gunung Putri Ds. Bojong Kulur Ds. Perburuan',
#        'Kec. Cibinong Kel. Nangewer', 'Kec. Sukajaya  Ds. Harkat Jaya',
#        'KEC SUKAJAYA', 'Kec.Sukaraja Ds. Cadas Ngampar',
#        'Kec. Jasinga Ds. Kalong Sawah Ds. Jugala Jaya Kec. Cibungbulang Ds. Cibatok Kec. Babakan Madang Ds. Cijayanti',
#        'KEC BABAKAN MADANG', 'Kec. Sukajaya Ds. Harkatjaya',
#        'Kec. Cibinong Ds. Nangewer Mekar',
# ...

# %%
banjir_bogor['Lokasi'].isnull().sum()
# Out:
# 74

# %%
from wordcloud import WordCloud, STOPWORDS

# %%
comment_words = ''
stopwords = set(STOPWORDS)

# %%
# iterate through the csv file
for val in banjir_bogor['Lokasi']:
     
    # typecaste each val3 to string
    val = str(val)
 
    # split the value
    tokens = val.split()
     
    # Converts each token into lowercase
    for i in range(len(tokens)):
        tokens[i] = tokens[i].lower()
        
    comment_words += " ".join(tokens)+" "

# %%
wordcloud = WordCloud(width = 800, height = 800,
                background_color ='white',
                stopwords = stopwords,
                min_font_size = 10).generate(comment_words)

# plot the WordCloud image                      
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
 
plt.show()

# %%
banjir_bogor['Lokasi'].str.count("Kec. Cisarua|KEC CISARUA").sum()
# Out:
# 9.0

# %%
banjir_bogor['Lokasi'].str.count("Kec. Cibinong|KEC CIBINONG").sum()
# Out:
# 16.0

# %%
banjir_bogor['Lokasi'].str.count("Kec. Bojonggede|KEC BOJONGGEDE").sum()
# Out:
# 14.0

# %%
banjir_bogor['Lokasi'].str.count("Kec. Sukajaya|KEC SUKAJAYA").sum()
# Out:
# 12.0

# %%
banjir_bogor['Lokasi'].str.count("Kec. Ciomas|KEC CIOMAS").sum()
# Out:
# 8.0
