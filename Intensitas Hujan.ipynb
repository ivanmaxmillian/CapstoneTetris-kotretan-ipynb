# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
data = pd.read_csv("C:/Users/ivanm/Documents/DOCUMENTS/BELAJAR/TETRIS/SQL/datasets/pr_timeseries_monthly_cru_202208011058.csv")

# %%
data.head(5)
# Out:
#    annual     Jan     Feb     Mar     Apr     May     Jun     Jul     Aug  \
# 0    1901  281.37  252.74  278.82  257.90  219.86  196.78  183.68  153.73
# 1    1902  280.33  270.40  273.60  245.76  222.07  159.56  140.03  162.85
# 2    1903  288.82  270.31  289.37  257.64  232.48  181.07  180.82  182.79
# 3    1904  295.04  246.24  267.21  265.40  228.93  179.98  182.89  160.97
# 4    1905  290.24  271.85  278.21  274.44  247.89  164.74  159.74  157.34
#
#       Sep     Oct     Nov     Dec    total
# 0  157.96  199.58  249.63  275.11  2707.16
# 1  142.41  171.40  213.32  274.35  2556.08
# 2  171.70  199.34  241.53  290.97  2786.84
# 3  178.73  229.01  242.22  302.03  2778.65
# 4  167.12  197.44  239.41  243.77  2692.19

# %%
# make data
x = data['annual']
y = data['total']

# plot
plt.plot(x, y) 

plt.show()

# %%
av_col = data[data['annual']>2009]
av_col
# Out:
#      annual     Jan     Feb     Mar     Apr     May     Jun     Jul     Aug  \
# 109    2010  291.03  234.80  329.90  311.54  294.01  246.39  222.65  235.89
# 110    2011  294.81  254.11  303.24  292.71  245.08  208.51  160.26  153.11
# 111    2012  276.10  281.84  332.41  282.31  258.17  165.02  164.07  158.59
# 112    2013  284.18  307.66  274.08  271.03  254.39  179.68  176.88  172.60
# 113    2014  272.82  173.98  227.66  283.23  220.75  188.07  161.47  185.47
# 114    2015  284.28  260.00  257.77  274.37  201.54  189.77  126.00  127.51
# 115    2016  255.41  289.54  285.03  260.43  249.11  201.86  198.48  176.99
# 116    2017  297.03  268.55  291.13  293.17  255.25  190.03  188.91  185.40
# 117    2018  276.44  264.34  306.73  266.20  245.44  191.11  191.39  141.44
# 118    2019  269.13  240.54  283.92  265.69  210.61  228.49  141.49  110.85
# 119    2020  257.15  250.76  284.09  317.46  249.95  214.01  213.70  164.01
# ...

# %%
av_col = av_col.mean(axis=0)
print (av_col)
# Out:
# annual    2015.500000
# Jan        281.345000
# Feb        256.116667
# Mar        290.908333
# Apr        280.744167
# May        244.504167
# Jun        200.889167
# Jul        176.892500
# Aug        170.196667
# Sep        183.328333
# Oct        211.472500
# Nov        272.201667
# Dec        301.901667
# total     2870.500833
# dtype: float64

# %%
pd.Series.to_frame(av_col)
# Out:
#                   0
# annual  2015.500000
# Jan      281.345000
# Feb      256.116667
# Mar      290.908333
# Apr      280.744167
# May      244.504167
# Jun      200.889167
# Jul      176.892500
# Aug      170.196667
# Sep      183.328333
# Oct      211.472500
# Nov      272.201667
# Dec      301.901667
# total   2870.500833

# %%
av_col = av_col.reset_index()

# %%
x = av_col.iloc[1:13, :]
x.head()
# Out:
#   index           0
# 1   Jan  281.345000
# 2   Feb  256.116667
# 3   Mar  290.908333
# 4   Apr  280.744167
# 5   May  244.504167

# %%
x[0]
# Out:
# 1     281.345000
# 2     256.116667
# 3     290.908333
# 4     280.744167
# 5     244.504167
# 6     200.889167
# 7     176.892500
# 8     170.196667
# 9     183.328333
# 10    211.472500
# 11    272.201667
# 12    301.901667
# Name: 0, dtype: float64

# %%
X= x['index']
Y= x[0]

plt.figure(figsize=(12,7))
plt.bar(X, Y)
plt.title('Rata-rata Intensitas Hujan Indonesia Setiap Bulan 1901-2020', size=16)
plt.ylabel('Precipitation (mm)', size=14)
plt.xticks(size=12)
plt.yticks(size=12)

plt.show()

# %%
data_annual = data[['annual', 'total']]
data_annual.head()
# Out:
#    annual    total
# 0    1901  2707.16
# 1    1902  2556.08
# 2    1903  2786.84
# 3    1904  2778.65
# 4    1905  2692.19

# %%
pd.Series.to_frame(data_annual['total'].describe())
# Out:
#              total
# count   121.000000
# mean   2762.805620
# std     182.981567
# min    2248.190000
# 25%    2648.840000
# 50%    2775.270000
# 75%    2890.040000
# max    3289.370000

# %%
data[data['annual']==2011]
# Out:
#      annual     Jan     Feb     Mar     Apr     May     Jun     Jul     Aug  \
# 110    2011  294.81  254.11  303.24  292.71  245.08  208.51  160.26  153.11
#
#         Sep     Oct     Nov    Dec    total
# 110  157.56  240.84  271.15  327.6  2908.98

# %%
data[data['total']<=2249]
data[data['total']>=3289.37]
# Out:
#      annual     Jan    Feb    Mar     Apr     May     Jun     Jul     Aug  \
# 109    2010  291.03  234.8  329.9  311.54  294.01  246.39  222.65  235.89
#
#         Sep     Oct     Nov     Dec    total
# 109  300.65  256.63  288.09  277.79  3289.37

# %%
last10years = data_annual[data_annual['annual']>2009]

x1 =last10years['annual']
y1 =last10years['total']

plt.figure(figsize=(12,7))
plt.plot(x1, y1)
plt.xticks(size=12)
plt.yticks(size=12)

plt.show()

# %%
last10years
# Out:
#      annual    total
# 109    2010  3289.37
# 110    2011  2908.98
# 111    2012  2866.87
# 112    2013  2908.13
# 113    2014  2601.31
# 114    2015  2482.19
# 115    2016  2947.51
# 116    2017  3017.19
# 117    2018  2823.95
# 118    2019  2512.98
# 119    2020  2999.82
# 120    2021  3087.71

# %%
data.tail(10)
# Out:
#      annual     Jan     Feb     Mar     Apr     May     Jun     Jul     Aug  \
# 111    2012  276.10  281.84  332.41  282.31  258.17  165.02  164.07  158.59
# 112    2013  284.18  307.66  274.08  271.03  254.39  179.68  176.88  172.60
# 113    2014  272.82  173.98  227.66  283.23  220.75  188.07  161.47  185.47
# 114    2015  284.28  260.00  257.77  274.37  201.54  189.77  126.00  127.51
# 115    2016  255.41  289.54  285.03  260.43  249.11  201.86  198.48  176.99
# 116    2017  297.03  268.55  291.13  293.17  255.25  190.03  188.91  185.40
# 117    2018  276.44  264.34  306.73  266.20  245.44  191.11  191.39  141.44
# 118    2019  269.13  240.54  283.92  265.69  210.61  228.49  141.49  110.85
# 119    2020  257.15  250.76  284.09  317.46  249.95  214.01  213.70  164.01
# 120    2021  317.76  247.28  314.94  250.79  249.75  207.73  177.41  230.50
#
#         Sep     Oct     Nov     Dec    total
# 111  165.82  207.29  284.63  290.62  2866.87
# ...

# %%
av_col2 = data.max(axis=0)

# %%
av_col2.head()
# Out:
# annual    2021.00
# Jan        348.54
# Feb        327.47
# Mar        353.50
# Apr        324.08
# dtype: float64
