# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
data_banjir = pd.read_excel('C:/Users/ivanm/Documents/DOCUMENTS/BELAJAR/TETRIS/Project/Data Bencana.xlsx')

# %%
data_banjir.head(5)
# Out:
#    No.  ID Kabupaten Tanggal Kejadian Kejadian  \
# 0    1          5304       2022-06-30   BANJIR
# 1    2          1709       2022-06-30   BANJIR
# 2    3          1701       2022-06-30   BANJIR
# 3    4          2104       2022-06-30   BANJIR
# 4    5          6201       2022-06-30   BANJIR
#
#                                               Lokasi             Kabupaten  \
# 0  Kec. Kualin  Ds. Toineke Kec.Amanatun Selatan ...  TIMOR TENGAH SELATAN
# 1  Kec. Talang Empat Ds. Pulau Panggung Ds. Jaya ...       BENGKULU TENGAH
# 2                     Kec. Pino Raya Ds.Telaga dalam      BENGKULU SELATAN
# 3  Kec. Singkep Kel. Dabo Lama Ds. Batu Berdaun D...                LINGGA
# 4  Kec. Pangkalan Banteng  Ds. Sungai Hijau Kec. ...    KOTAWARINGIN BARAT
#
#               Provinsi Kronologi & Dokumentasi  \
# 0  NUSA TENGGARA TIMUR                     NaN
# 1             BENGKULU                     NaN
# 2             BENGKULU                     NaN
# ...

# %%
data_banjir['Penyebab'].fillna(data_banjir['Kronologi & Dokumentasi'], inplace=True)

# %%
banjir_cilacap = data_banjir[data_banjir['Kabupaten'] == 'CILACAP']

# %%
banjir_cilacap
# Out:
#          No.  ID Kabupaten Tanggal Kejadian Kejadian  \
# 15        16          3301       2022-06-26   BANJIR
# 106      107          3301       2022-05-25   BANJIR
# 146      147          3301       2022-05-19   BANJIR
# 248      249          3301       2022-04-20   BANJIR
# 251      252          3301       2022-04-20   BANJIR
# ...      ...           ...              ...      ...
# 11707  11708          3301       2010-02-22   BANJIR
# 11754  11755          3301       2010-02-13   BANJIR
# 11872  11873          3301       2010-01-21   BANJIR
# 11877  11878          3301       2010-01-20   BANJIR
# 11887  11888          3301       2010-01-18   BANJIR
#
#                                                   Lokasi Kabupaten  \
# 15     Kec. Cipari Ds. Cisuru Ds. Serang Kec. Bantars...   CILACAP
# 106          Kec. Bantarsari Ds. Bantarsari Ds. Rawajaya   CILACAP
# 146    Kec. Nusawungu Ds. Jetis grumbul sirendeng Ds....   CILACAP
# ...

# %%
banjir_cilacap['Lokasi'].describe()
# Out:
# count                           61
# unique                          61
# top       Kec. Adipala Ds. Adiraja
# freq                             1
# Name: Lokasi, dtype: object

# %%
banjir_cilacap['Lokasi'].value_counts()
# Out:
# Kec. Adipala Ds. Adiraja                                                           1
# Kec. Bantarsari Desa Bulaksari                                                     1
# Kec. Kampung Laut Ds. Ujunggagak Ds. Panikel                                       1
# Desa Adireja Kec. Adipala                                                          1
# KEC. DAYEUHLUHUR DS. PANULISAN TIMUR KEC. WANAREJA DS. MADURA KEC. KARANGPUCUNG    1
#                                                                                   ..
# KEC. KESUGIHAN DS. DONDONG                                                         1
# KEC. WANAREJA  KEC. MAJENANG                                                       1
# KEC. WANAREJA DS. TARISI KEC. GANDRUNGMANGU DS. WRINGINHARJO                       1
# Kec. Wanareja Ds. Wanareja                                                         1
# Kec. Cipari Ds. Caruy                                                              1
# Name: Lokasi, Length: 61, dtype: int64

# %%
from wordcloud import WordCloud, STOPWORDS

# %%
comment_words = ''
stopwords = set(STOPWORDS)

# %%
# iterate through the csv file
for val in banjir_cilacap['Lokasi']:
     
    # typecaste each val3 to string
    val = str(val)
 
    # split the value
    tokens = val.split()
     
    # Converts each token into lowercase
    for i in range(len(tokens)):
        tokens[i] = tokens[i].lower()
        
    comment_words += " ".join(tokens)+" "

# %%
wordcloud = WordCloud(width = 800, height = 800,
                background_color ='white',
                stopwords = stopwords,
                min_font_size = 10).generate(comment_words)

# plot the WordCloud image                      
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
 
plt.show()

# %%
banjir_cilacap['Lokasi'].str.count("Kec. Wanareja|KEC WANAREJA").sum()
# Out:
# 13.0

# %%
banjir_cilacap['Lokasi'].str.count("Kec. Sidareja|KEC SIDAREJA").sum()
# Out:
# 8.0

# %%
banjir_cilacap['Lokasi'].str.count("Kec. Majenang|KEC MAJENANG").sum()
# Out:
# 12.0
